# %%
from engine.dtree3 import *

attr, data = get_data()

sub_set = get_sub_sets(attr[1:-1], data)

sub_set
# Out:
# [[{'label': '是', '色泽': '青绿'},
#   {'label': '是', '色泽': '乌黑'},
#   {'label': '是', '色泽': '乌黑'},
#   {'label': '是', '色泽': '青绿'},
#   {'label': '是', '色泽': '浅白'},
#   {'label': '是', '色泽': '青绿'},
#   {'label': '是', '色泽': '乌黑'},
#   {'label': '是', '色泽': '乌黑'},
#   {'label': '否', '色泽': '乌黑'},
#   {'label': '否', '色泽': '青绿'},
#   {'label': '否', '色泽': '浅白'},
#   {'label': '否', '色泽': '浅白'},
#   {'label': '否', '色泽': '青绿'},
#   {'label': '否', '色泽': '浅白'},
#   {'label': '否', '色泽': '乌黑'},
#   {'label': '否', '色泽': '浅白'},
#   {'label': '否', '色泽': '青绿'}],
#  [{'label': '是', '根蒂': '蜷缩'},
#   {'label': '是', '根蒂': '蜷缩'},
#   {'label': '是', '根蒂': '蜷缩'},
#   {'label': '是', '根蒂': '蜷缩'},
#   {'label': '是', '根蒂': '蜷缩'},
#   {'label': '是', '根蒂': '稍蜷'},
#   {'label': '是', '根蒂': '稍蜷'},
#   {'label': '是', '根蒂': '稍蜷'},
#   {'label': '否', '根蒂': '稍蜷'},
#   {'label': '否', '根蒂': '硬挺'},
#   {'label': '否', '根蒂': '硬挺'},
#   {'label': '否', '根蒂': '蜷缩'},
#   {'label': '否', '根蒂': '稍蜷'},
#   {'label': '否', '根蒂': '稍蜷'},
# ...
